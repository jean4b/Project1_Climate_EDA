# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Data Analysis of Singapore Rainfall

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### Choose your Data
#
# There are 2 datasets included in the [`data`](./data/) folder for this project. These correponds to rainfall information.
#
# * [`rainfall-monthly-number-of-rain-days.csv`](./data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`rainfall-monthly-total.csv`](./data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022
#
# Other relevant weather datasets from [data.gov.sg](data.gov.sg) that you can download and use are as follows:
#
# * [Relative Humidity](https://data.gov.sg/dataset/relative-humidity-monthly-mean)
# * [Monthly Maximum Daily Rainfall](https://data.gov.sg/dataset/rainfall-monthly-maximum-daily-total)
# * [Hourly wet buld temperature](https://data.gov.sg/dataset/wet-bulb-temperature-hourly)
# * [Monthly mean sunshine hours](https://data.gov.sg/dataset/sunshine-duration-monthly-mean-daily-duration)
# * [Surface Air Temperature](https://data.gov.sg/dataset/surface-air-temperature-mean-daily-minimum)
#
# You can also use other datasets for your analysis, make sure to cite the source when you are using them

# %% [markdown]
# **To-Do:**
# - day_rain = 'rainfall-monthly-number-of-rain-days.csv'
# - month_rain = 'rainfall-monthly-total.csv'
# - humid_df = 'RelativeHumidityMonthlyMean.csv'
# - sunshine_df = 'SunshineDurationMonthlyMeanDailyDuration.csv'
# - wetbulb_df = 'WetBulbTemperatureHourly.csv'
# - tempmean_df = 'SurfaceAirTemperatureMonthlyMean.csv'
# https://beta.data.gov.sg/collections/1419/view
# - visitor_df = 'TotalVisitorInternationalArrivalsMonthly.csv'
# https://beta.data.gov.sg/collections/1622/view

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** Singapore situated in tropical region leads to the country being affected by multiple rainfalls in a year. As an analyst for the tourism industry, my analysis on the climate and international visitors data will help see the trends and gain insights of Singapore's climate throughout the period of 40 years, as well as the trend of international visitors visiting Singapore. The analysis will also help understand factors that contributed to rainfall. Ultimately, these insights will transform into recommendations for the tourism industry in identifying the periods that are optimal to visit Singapore and announce publicly to visitors worldwide.

# %% [markdown]
# Rainfall affects daily activities of Singapore population, hence it is worth analysing rainfall data to identify trends

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on how climate change is affecting different industries or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# - Increase in rainfall affects the decline of international visitors by 10%, however, the temperature has no negative impact on the number of visitors (fauzel, 2019)
# - November to January are the wettest months in Singapore (Met Office, n.d.)
# - July and August are high seasons with highest amount of visitors and the highest hotel room prices (Dettmar, 2022)
#
# References:
# - Dettmar, R. (2022). Singapore Tourism Statistics for 2022 - Who Visited Singapore the Most? [online] Atlys. Available at: https://www.atlys.com/en-IN/post/singapore-tourism-statistics.
# - Fauzel, S. (2019). The impact of changes in temperature and precipitation on tourists arrival: An ARDL analysis for the case of a SIDS. Current Issues in Tourism, pp.1–7. doi:https://doi.org/10.1080/13683500.2019.1639639.
# - Met Office (n.d.). Singapore weather. [online] Met Office. Available at: https://www.metoffice.gov.uk/weather/travel/holiday-weather/asia/singapore#:~:text=Singapore%20has%20a%20very%20wet.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Mean function:
def mean(lst):
    mean = sum(lst)/len(lst)
    return mean

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Standard Deviation function:
def calculate_std_dev(lst):
    mean = sum(lst) / len(lst)
    variance = sum((xi - mean) ** 2 for xi in lst) / len(lst)
    std_dev = variance ** 0.5
    return std_dev

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import all the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary. Make sure to comment your code to showcase the intent behind the data processing step.
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values and datatype.
# 3. Check for any obvious issues with the observations.
# 4. Fix any errors you identified in steps 2-3.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If the month column data is better analyzed as month and year, create new columns for the same
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
#     - Since different climate metrics are in month format, you can merge them into one single dataframe for easier analysis
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

# %%
# Import data
day_rain = pd.read_csv('rainfall-monthly-number-of-rain-days.csv')
month_rain = pd.read_csv('rainfall-monthly-total.csv')
humid_df = pd.read_csv('RelativeHumidityMonthlyMean.csv')
sunshine_df = pd.read_csv('SunshineDurationMonthlyMeanDailyDuration.csv')
wetbulb_df = pd.read_csv('WetBulbTemperatureHourly.csv')
tempmean_df = pd.read_csv('SurfaceAirTemperatureMonthlyMean.csv')
visitor_df = pd.read_csv('TotalVisitorInternationalArrivalsMonthly.csv')

# %%
# Check data - day_rain
day_rain.head()
# Out:
#      month  no_of_rainy_days
# 0  1982-01                10
# 1  1982-02                 5
# 2  1982-03                11
# 3  1982-04                14
# 4  1982-05                10

# %%
# Check data - month_rain
month_rain.head()
# Out:
#      month  total_rainfall
# 0  1982-01           107.1
# 1  1982-02            27.8
# 2  1982-03           160.8
# 3  1982-04           157.0
# 4  1982-05           102.2

# %%
# Check data - humid_df
humid_df.head()
# Out:
#      month  mean_rh
# 0  1982-01     81.2
# 1  1982-02     79.5
# 2  1982-03     82.3
# 3  1982-04     85.9
# 4  1982-05     83.2

# %%
# Check data - sunshine_df
sunshine_df.head()
# Out:
#      month  mean_sunshine_hrs
# 0  1982-01                5.6
# 1  1982-02                7.6
# 2  1982-03                5.1
# 3  1982-04                4.7
# 4  1982-05                5.8

# %%
# Check data - wetbulb_df
wetbulb_df.head()
# Out:
#      wbt_date  wbt_time  wet_bulb_temperature
# 0  1982-01-01         1                  24.7
# 1  1982-01-01         2                  24.5
# 2  1982-01-01         3                  24.3
# 3  1982-01-01         4                  24.2
# 4  1982-01-01         5                  24.2

# %%
# Check data - tempmean_df
tempmean_df.head()
# Out:
#      month  mean_temp
# 0  1982-01       25.9
# 1  1982-02       27.1
# 2  1982-03       27.2
# 3  1982-04       27.0
# 4  1982-05       28.0

# %%
# Check data - visitor_df
visitor_df.head()
# Out:
#      month  total_international_visitor_arrivals
# 0  1978-01                                167016
# 1  1978-02                                147954
# 2  1978-03                                163199
# 3  1978-04                                162400
# 4  1978-05                                162667

# %% [markdown]
# 2. Check for missing values and datatype.

# %%
# check info - day_rain
day_rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             488 non-null    object
#  1   no_of_rainy_days  488 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8+ KB

# %%
# check info - month_rain
month_rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   month           488 non-null    object
#  1   total_rainfall  488 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB

# %%
# check info - humid_df
humid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month    499 non-null    object
#  1   mean_rh  499 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.9+ KB

# %%
# check info - sunshine_df
sunshine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   month              499 non-null    object
#  1   mean_sunshine_hrs  499 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.9+ KB

# %%
# check info - wetbulb_df
wetbulb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364488 entries, 0 to 364487
# Data columns (total 3 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   wbt_date              364488 non-null  object
#  1   wbt_time              364488 non-null  int64
#  2   wet_bulb_temperature  364488 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 8.3+ MB

# %%
# check info - tempmean_df
tempmean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   month      499 non-null    object
#  1   mean_temp  499 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.9+ KB

# %%
# check info - visitor_df
visitor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455 entries, 0 to 454
# Data columns (total 2 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   month                                 455 non-null    object
#  1   total_international_visitor_arrivals  455 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# change column name from month to data
day_rain.rename(columns={'month':'date'}, inplace=True)
month_rain.rename(columns={'month':'date'}, inplace=True)
humid_df.rename(columns={'month':'date'}, inplace=True)
sunshine_df.rename(columns={'month': 'date'}, inplace=True)
wetbulb_df.rename(columns={'wbt_date': 'date'}, inplace=True)
tempmean_df.rename(columns={'month': 'date'}, inplace=True)
visitor_df.rename(columns={'month': 'date'}, inplace=True)

# %%
# Set index as date then join day_rain data with month_rain data
rain_df = day_rain.set_index('date').join(month_rain.set_index('date'), how='left')
rain_df
# Out:
#          no_of_rainy_days  total_rainfall
# date
# 1982-01                10           107.1
# 1982-02                 5            27.8
# 1982-03                11           160.8
# 1982-04                14           157.0
# 1982-05                10           102.2
# ...                   ...             ...
# 2022-04                18           239.6
# 2022-05                12           102.0
# 2022-06                17           211.8
# 2022-07                16           145.2
# 2022-08                15           141.4
#
# [488 rows x 2 columns]

# %%
# reset index of rain_df
rain_df.reset_index(inplace=True)
rain_df.head()
# Out:
#       date  no_of_rainy_days  total_rainfall
# 0  1982-01                10           107.1
# 1  1982-02                 5            27.8
# 2  1982-03                11           160.8
# 3  1982-04                14           157.0
# 4  1982-05                10           102.2

# %%
# create 2 new columns: year and month of each dataset
rain_df['year'] = pd.DatetimeIndex(rain_df['date']).year
rain_df['month'] = pd.DatetimeIndex(rain_df['date']).month
humid_df['year'] = pd.DatetimeIndex(humid_df['date']).year
humid_df['month'] = pd.DatetimeIndex(humid_df['date']).month
sunshine_df['year'] = pd.DatetimeIndex(sunshine_df['date']).year
sunshine_df['month'] = pd.DatetimeIndex(sunshine_df['date']).month
wetbulb_df['year'] = pd.DatetimeIndex(wetbulb_df['date']).year
wetbulb_df['month'] = pd.DatetimeIndex(wetbulb_df['date']).month
tempmean_df['year'] = pd.DatetimeIndex(tempmean_df['date']).year
tempmean_df['month'] = pd.DatetimeIndex(tempmean_df['date']).month
visitor_df['year'] = pd.DatetimeIndex(visitor_df['date']).year
visitor_df['month'] = pd.DatetimeIndex(visitor_df['date']).month

# %%
# delete wbt_time column
wetbulb_df.drop('wbt_time', axis=1, inplace=True)
wetbulb_df.head()
# Out:
#          date  wet_bulb_temperature  year  month
# 0  1982-01-01                  24.7  1982      1
# 1  1982-01-01                  24.5  1982      1
# 2  1982-01-01                  24.3  1982      1
# 3  1982-01-01                  24.2  1982      1
# 4  1982-01-01                  24.2  1982      1

# %%
# group wetbulb df by mean wet bulb temperature by year and month
grouped_df1 = wetbulb_df.groupby(['year', 'month'])['wet_bulb_temperature'].mean()

# %%
grouped_df1
# Out:
# year  month
# 1982  1        23.456048
#       2        24.297619
#       3        24.811559
#       4        25.103750
#       5        25.689651
#                  ...
# 2023  3        24.308199
#       4        25.440139
#       5        25.754435
#       6        25.562639
#       7        25.300269
# Name: wet_bulb_temperature, Length: 499, dtype: float64

# %%
# reset index of grouped_df1
wetbulb_avg1 = grouped_df1.reset_index()

# %%
wetbulb_avg1
# Out:
#      year  month  wet_bulb_temperature
# 0    1982      1             23.456048
# 1    1982      2             24.297619
# 2    1982      3             24.811559
# 3    1982      4             25.103750
# 4    1982      5             25.689651
# ..    ...    ...                   ...
# 494  2023      3             24.308199
# 495  2023      4             25.440139
# 496  2023      5             25.754435
# 497  2023      6             25.562639
# 498  2023      7             25.300269
#
# [499 rows x 3 columns]

# %%
# drop rows from year 1978-1981
visitor_df.drop(visitor_df.index[0:48], inplace=True)

# %%
visitor_df
# Out:
#         date  total_international_visitor_arrivals  year  month
# 48   1982-01                                239088  1982      1
# 49   1982-02                                225008  1982      2
# 50   1982-03                                235113  1982      3
# 51   1982-04                                225827  1982      4
# 52   1982-05                                232737  1982      5
# ..       ...                                   ...   ...    ...
# 450  2015-07                               1519188  2015      7
# 451  2015-08                               1445052  2015      8
# 452  2015-09                               1131967  2015      9
# 453  2015-10                               1246706  2015     10
# 454  2015-11                               1193906  2015     11
#
# [407 rows x 4 columns]

# %%
# merge each dataset to rain_df
rain_df = pd.merge(rain_df, humid_df, on=['date', 'year', 'month'], how='left')
rain_df = pd.merge(rain_df, sunshine_df, on=['date', 'year', 'month'], how='left')
rain_df = pd.merge(rain_df, wetbulb_avg1, on=['year','month'], how='left')
rain_df = pd.merge(rain_df, tempmean_df, on=['date', 'year','month'], how='left')
rain_df = pd.merge(rain_df, visitor_df, on=['date', 'year', 'month'], how='left')

# %%
rain_df.head()
# Out:
#       date  no_of_rainy_days  total_rainfall  year  month  mean_rh  \
# 0  1982-01                10           107.1  1982      1     81.2
# 1  1982-02                 5            27.8  1982      2     79.5
# 2  1982-03                11           160.8  1982      3     82.3
# 3  1982-04                14           157.0  1982      4     85.9
# 4  1982-05                10           102.2  1982      5     83.2
#
#    mean_sunshine_hrs  wet_bulb_temperature  mean_temp  \
# 0                5.6             23.456048       25.9
# 1                7.6             24.297619       27.1
# 2                5.1             24.811559       27.2
# 3                4.7             25.103750       27.0
# 4                5.8             25.689651       28.0
#
#    total_international_visitor_arrivals
# 0                              239088.0
# 1                              225008.0
# 2                              235113.0
# 3                              225827.0
# ...

# %%
# round wet bulb temperature to 1 decimal
rain_df['wet_bulb_temperature'] = round(rain_df['wet_bulb_temperature'], 1)

# %%
# rename mean_rh and mean_temp columns
rain_df.rename(columns={'mean_rh': 'mean_relative_humidity'}, inplace=True)
rain_df.rename(columns={'mean_temp': 'mean_temperature'}, inplace=True)

# %%
rain_df.head()
# Out:
#       date  no_of_rainy_days  total_rainfall  year  month  \
# 0  1982-01                10           107.1  1982      1
# 1  1982-02                 5            27.8  1982      2
# 2  1982-03                11           160.8  1982      3
# 3  1982-04                14           157.0  1982      4
# 4  1982-05                10           102.2  1982      5
#
#    mean_relative_humidity  mean_sunshine_hrs  wet_bulb_temperature  \
# 0                    81.2                5.6                  23.5
# 1                    79.5                7.6                  24.3
# 2                    82.3                5.1                  24.8
# 3                    85.9                4.7                  25.1
# 4                    83.2                5.8                  25.7
#
#    mean_temperature  total_international_visitor_arrivals
# 0              25.9                              239088.0
# 1              27.1                              225008.0
# ...

# %%
rain_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date                                  488 non-null    object
#  1   no_of_rainy_days                      488 non-null    int64
#  2   total_rainfall                        488 non-null    float64
#  3   year                                  488 non-null    int32
#  4   month                                 488 non-null    int32
#  5   mean_relative_humidity                488 non-null    float64
#  6   mean_sunshine_hrs                     488 non-null    float64
#  7   wet_bulb_temperature                  488 non-null    float64
#  8   mean_temperature                      488 non-null    float64
#  9   total_international_visitor_arrivals  407 non-null    float64
# dtypes: float64(6), int32(2), int64(1), object(1)
# ...

# %%
# change rain_df date column from object to datetime
rain_df['date'] = pd.to_datetime(rain_df['date'])

# %%
rain_df.head()
# Out:
#         date  no_of_rainy_days  total_rainfall  year  month  \
# 0 1982-01-01                10           107.1  1982      1
# 1 1982-02-01                 5            27.8  1982      2
# 2 1982-03-01                11           160.8  1982      3
# 3 1982-04-01                14           157.0  1982      4
# 4 1982-05-01                10           102.2  1982      5
#
#    mean_relative_humidity  mean_sunshine_hrs  wet_bulb_temperature  \
# 0                    81.2                5.6                  23.5
# 1                    79.5                7.6                  24.3
# 2                    82.3                5.1                  24.8
# 3                    85.9                4.7                  25.1
# 4                    83.2                5.8                  25.7
#
#    mean_temperature  total_international_visitor_arrivals
# 0              25.9                              239088.0
# 1              27.1                              225008.0
# ...

# %%
rain_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date                                  488 non-null    datetime64[ns]
#  1   no_of_rainy_days                      488 non-null    int64
#  2   total_rainfall                        488 non-null    float64
#  3   year                                  488 non-null    int32
#  4   month                                 488 non-null    int32
#  5   mean_relative_humidity                488 non-null    float64
#  6   mean_sunshine_hrs                     488 non-null    float64
#  7   wet_bulb_temperature                  488 non-null    float64
#  8   mean_temperature                      488 non-null    float64
#  9   total_international_visitor_arrivals  407 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int32(2), int64(1)
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |total_rainfall|float|rainfall-monthly-total|Total rainfall in mm|
# |no_of_rainy_days|int|rainfall-monthly-number-of-rain-days|Number of rain days in each month in days|
# |mean_rh|float|RelativeHumidityMonthlyMean|Monthly mean of relative humidity in percentage|
# |mean_sunshine_hrs|float|SunshineDurationMonthlyMeanDailyDuration|monthly mean of daily sunshine duration in hours|
# |wet_bulb_temperature|float|WetBulbTemperatureHourly|Wet bulb temperature, hourly in celsius|
# |mean_temp|float|SurfaceAirTemperatureMonthlyMean|Monthly temperature mean in celsius|
# |total_international_visitor_arrivals|int|TotalVisitorInternationalArrivalsMonthly|Number of international arrival visitors in thousands|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# Print overview of the dataframe
rain_df.head()
# Out:
#         date  no_of_rainy_days  total_rainfall  year  month  \
# 0 1982-01-01                10           107.1  1982      1
# 1 1982-02-01                 5            27.8  1982      2
# 2 1982-03-01                11           160.8  1982      3
# 3 1982-04-01                14           157.0  1982      4
# 4 1982-05-01                10           102.2  1982      5
#
#    mean_relative_humidity  mean_sunshine_hrs  wet_bulb_temperature  \
# 0                    81.2                5.6                  23.5
# 1                    79.5                7.6                  24.3
# 2                    82.3                5.1                  24.8
# 3                    85.9                4.7                  25.1
# 4                    83.2                5.8                  25.7
#
#    mean_temperature  total_international_visitor_arrivals
# 0              25.9                              239088.0
# 1              27.1                              225008.0
# ...

# %%
# Summary statistics
rain_df.describe(include='all')
# Out:
#                                 date  no_of_rainy_days  total_rainfall  \
# count                            488        488.000000      488.000000
# mean   2002-04-16 16:55:04.918032768         14.061475      177.163730
# min              1982-01-01 00:00:00          1.000000        0.200000
# 25%              1992-02-22 18:00:00         11.000000       93.850000
# 50%              2002-04-16 00:00:00         14.000000      159.450000
# 75%              2012-06-08 12:00:00         18.000000      238.075000
# max              2022-08-01 00:00:00         27.000000      765.900000
# std                              NaN          4.947394      113.916029
#
#               year       month  mean_relative_humidity  mean_sunshine_hrs  \
# count   488.000000  488.000000              488.000000         488.000000
# mean   2001.836066    6.467213               82.247541           5.688320
# min    1982.000000    1.000000               72.000000           2.700000
# ...

# %%
# Summary columns information
rain_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date                                  488 non-null    datetime64[ns]
#  1   no_of_rainy_days                      488 non-null    int64
#  2   total_rainfall                        488 non-null    float64
#  3   year                                  488 non-null    int32
#  4   month                                 488 non-null    int32
#  5   mean_relative_humidity                488 non-null    float64
#  6   mean_sunshine_hrs                     488 non-null    float64
#  7   wet_bulb_temperature                  488 non-null    float64
#  8   mean_temperature                      488 non-null    float64
#  9   total_international_visitor_arrivals  407 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int32(2), int64(1)
# ...

# %%
# Find standard deviation of each column
std_dev = {'no_of_rainy_days': calculate_std_dev(rain_df['no_of_rainy_days']),
    'total_rainfall' : calculate_std_dev(rain_df['total_rainfall']),
    'mean_relative_humidity': calculate_std_dev(rain_df['mean_relative_humidity']),
    'mean_sunshine_hrs': calculate_std_dev(rain_df['mean_sunshine_hrs']),
    'wet_bulb_temperature' : calculate_std_dev(rain_df['wet_bulb_temperature']),
    'mean_temperature':  calculate_std_dev(rain_df['mean_temperature'])
}

std_dev
# Out:
# {'no_of_rainy_days': 4.9423221913224085,
#  'total_rainfall': 113.79925170470057,
#  'mean_relative_humidity': 3.4104399291902836,
#  'mean_sunshine_hrs': 1.2044686452879794,
#  'wet_bulb_temperature': 0.5932888791314476,
#  'mean_temperature': 0.8013725449868125}

# %%
rain_df.columns
# Out:
# Index(['date', 'no_of_rainy_days', 'total_rainfall', 'year', 'month',
#        'mean_relative_humidity', 'mean_sunshine_hrs', 'wet_bulb_temperature',
#        'mean_temperature', 'total_international_visitor_arrivals'],
#       dtype='object')

# %%
# month has the highest total rainfall in 1990

rain_df.loc[rain_df['year']==1990][['year', 'month', 'total_rainfall']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      year  month  total_rainfall
# 104  1990      9           204.5

# %%
# month has the lowest total rainfall in 1990
rain_df.loc[rain_df['year']==1990][['year', 'month', 'total_rainfall']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#     year  month  total_rainfall
# 97  1990      2            24.1

# %%
# month has the highest total rainfall in 1990

rain_df.loc[rain_df['year']==1990][['year', 'month', 'total_rainfall', 'mean_relative_humidity', 'mean_temperature', 'wet_bulb_temperature']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      year  month  total_rainfall  mean_relative_humidity  mean_temperature  \
# 104  1990      9           204.5                    83.2              27.2
#
#      wet_bulb_temperature
# 104                  25.0

# %%
# month has the highest total rainfall in 1990

rain_df.loc[rain_df['year']==1990][['year', 'month', 'total_rainfall', 'mean_relative_humidity', 'mean_temperature','wet_bulb_temperature']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#     year  month  total_rainfall  mean_relative_humidity  mean_temperature  \
# 97  1990      2            24.1                    80.9              27.6
#
#     wet_bulb_temperature
# 97                  25.0

# %%
# month has the highest total rainfall in 2000

rain_df.loc[rain_df['year']==2000][['month', 'total_rainfall']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      month  total_rainfall
# 226     11           385.7

# %%
# Which month has the lowest total rainfall in 2000

rain_df.loc[rain_df['year']==2000][['month', 'total_rainfall']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#      month  total_rainfall
# 224      9            81.1

# %%
# month has the highest total rainfall in 2000

rain_df.loc[rain_df['year']==2000][['year', 'month', 'total_rainfall', 'mean_relative_humidity', 'mean_temperature', 'wet_bulb_temperature']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      year  month  total_rainfall  mean_relative_humidity  mean_temperature  \
# 226  2000     11           385.7                    87.1              27.3
#
#      wet_bulb_temperature
# 226                  25.6

# %%
# month has the lowest total rainfall in 2000

rain_df.loc[rain_df['year']==2000][['year', 'month', 'total_rainfall', 'mean_relative_humidity', 'mean_temperature','wet_bulb_temperature']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#      year  month  total_rainfall  mean_relative_humidity  mean_temperature  \
# 224  2000      9            81.1                    82.2              28.0
#
#      wet_bulb_temperature
# 224                  25.6

# %%
# month has the highest total rainfall in 2010 

rain_df.loc[rain_df['year']==2010][['month', 'total_rainfall']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      month  total_rainfall
# 342      7           298.5

# %%
# month has the lowest total rainfall in 2010 

rain_df.loc[rain_df['year']==2010][['month', 'total_rainfall']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#      month  total_rainfall
# 337      2             6.3

# %%
# month has the highest total rainfall in 2010 

rain_df.loc[rain_df['year']==2010][['year', 'month', 'total_rainfall', 'mean_relative_humidity', 'mean_temperature', 'wet_bulb_temperature']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      year  month  total_rainfall  mean_relative_humidity  mean_temperature  \
# 342  2010      7           298.5                    84.8              27.7
#
#      wet_bulb_temperature
# 342                  25.6

# %%
# month has the highest total rainfall in 2010 

rain_df.loc[rain_df['year']==2010][['year', 'month', 'total_rainfall', 'mean_relative_humidity', 'mean_temperature', 'wet_bulb_temperature']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#      year  month  total_rainfall  mean_relative_humidity  mean_temperature  \
# 337  2010      2             6.3                    77.3              28.9
#
#      wet_bulb_temperature
# 337                  25.6

# %%
# Which month has the highest total rainfall in 2020

rain_df.loc[rain_df['year']==2020][['month', 'total_rainfall']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      month  total_rainfall
# 460      5           255.6

# %%
# Which month has the lowest total rainfall in 2020

rain_df.loc[rain_df['year']==2020][['month', 'total_rainfall']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#      month  total_rainfall
# 457      2            65.0

# %%
# Which month has the highest total rainfall in 2020

rain_df.loc[rain_df['year']==2020][['year', 'month', 'total_rainfall', 'mean_relative_humidity', 'wet_bulb_temperature']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      year  month  total_rainfall  mean_relative_humidity  wet_bulb_temperature
# 460  2020      5           255.6                    79.1                  26.0

# %%
# Which month has the highest total rainfall in 2020

rain_df.loc[rain_df['year']==2020][['year', 'month', 'total_rainfall', 'mean_relative_humidity', 'mean_temperature', 'wet_bulb_temperature']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#      year  month  total_rainfall  mean_relative_humidity  mean_temperature  \
# 457  2020      2            65.0                    76.0              27.9
#
#      wet_bulb_temperature
# 457                  24.5

# %%
# Which year has the highest total rainfall in the date range of analysis?
rain_df[['year', 'total_rainfall']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      year  total_rainfall
# 299  2006           765.9

# %%
# Which year has the lowest total rainfall in the date range of analysis?
rain_df[['year', 'total_rainfall']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#      year  total_rainfall
# 385  2014             0.2

# %%
# Which month has the highest number of rainy days in 1990
rain_df.loc[rain_df['year']==1990][['month', 'no_of_rainy_days']].sort_values(by='no_of_rainy_days', ascending=False).head(1)
# Out:
#      month  no_of_rainy_days
# 104      9                17

# %%
# Which month has the lowest number of rainy days in 1990
rain_df.loc[rain_df['year']==1990][['month', 'no_of_rainy_days']].sort_values(by='no_of_rainy_days', ascending=True).head(1)
# Out:
#     month  no_of_rainy_days
# 98      3                 4

# %%
# Which month has the highest number of rainy days in 2000
rain_df.loc[rain_df['year']==2000][['month', 'no_of_rainy_days']].sort_values(by='no_of_rainy_days', ascending=False).head(1)
# Out:
#      month  no_of_rainy_days
# 226     11                21

# %%
# Which month has the lowest number of rainy days in 2000
rain_df.loc[rain_df['year']==2000][['month', 'no_of_rainy_days']].sort_values(by='no_of_rainy_days', ascending=True).head(1)
# Out:
#      month  no_of_rainy_days
# 220      5                10

# %%
# Which month has the highest number of rainy days in 2010
rain_df.loc[rain_df['year']==2010][['month', 'no_of_rainy_days']].sort_values(by='no_of_rainy_days', ascending=False).head(1)
# Out:
#      month  no_of_rainy_days
# 346     11                21

# %%
# Which month has the lowest number of rainy days in 2010
rain_df.loc[rain_df['year']==2010][['month', 'no_of_rainy_days']].sort_values(by='no_of_rainy_days', ascending=True).head(1)
# Out:
#      month  no_of_rainy_days
# 337      2                 4

# %%
# Which month has the highest number of rainy days in 2020?
rain_df.loc[rain_df['year']==2020][['month', 'no_of_rainy_days']].sort_values(by='no_of_rainy_days', ascending=False).head(1)
# Out:
#      month  no_of_rainy_days
# 462      7                22

# %%
# Which month has the lowest number of rainy days in 2020?
rain_df.loc[rain_df['year']==2020][['month', 'no_of_rainy_days']].sort_values(by='no_of_rainy_days', ascending=True).head(1)
# Out:
#      month  no_of_rainy_days
# 456      1                 6

# %%
# Which year has the highest number of rainy days in the date range of analysis?
rain_df[['year', 'no_of_rainy_days']].sort_values(by='no_of_rainy_days', ascending=False).head(1)
# Out:
#      year  no_of_rainy_days
# 442  2018                27

# %%
# Which year has the lowest number of rainy days in the date range of analysis?
rain_df[['year', 'no_of_rainy_days']].sort_values(by='no_of_rainy_days', ascending=True).head(1)
# Out:
#      year  no_of_rainy_days
# 385  2014                 1

# %%
# month has the highest total rainfall in 1990

rain_df.loc[rain_df['year']==1990][['year', 'month', 'total_rainfall', 'no_of_rainy_days' ,'mean_relative_humidity', 'wet_bulb_temperature', 'mean_temperature']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      year  month  total_rainfall  no_of_rainy_days  mean_relative_humidity  \
# 104  1990      9           204.5                17                    83.2
#
#      wet_bulb_temperature  mean_temperature
# 104                  25.0              27.2

# %%
# month has the highest total rainfall in 1990

rain_df.loc[rain_df['year']==1990][['year', 'month', 'total_rainfall', 'no_of_rainy_days' , 'mean_relative_humidity', 'wet_bulb_temperature', 'mean_temperature']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#     year  month  total_rainfall  no_of_rainy_days  mean_relative_humidity  \
# 97  1990      2            24.1                 8                    80.9
#
#     wet_bulb_temperature  mean_temperature
# 97                  25.0              27.6

# %%
# month has the highest total rainfall in 2000

rain_df.loc[rain_df['year']==2000][['year', 'month', 'total_rainfall', 'no_of_rainy_days','mean_relative_humidity', 'wet_bulb_temperature', 'mean_temperature']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      year  month  total_rainfall  no_of_rainy_days  mean_relative_humidity  \
# 226  2000     11           385.7                21                    87.1
#
#      wet_bulb_temperature  mean_temperature
# 226                  25.6              27.3

# %%
# month has the lowest total rainfall in 2000

rain_df.loc[rain_df['year']==2000][['year', 'month', 'total_rainfall', 'no_of_rainy_days', 'mean_relative_humidity', 'wet_bulb_temperature', 'mean_temperature']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#      year  month  total_rainfall  no_of_rainy_days  mean_relative_humidity  \
# 224  2000      9            81.1                12                    82.2
#
#      wet_bulb_temperature  mean_temperature
# 224                  25.6              28.0

# %%
# month has the highest total rainfall in 2010

rain_df.loc[rain_df['year']==2010][['year', 'month', 'total_rainfall', 'no_of_rainy_days', 'mean_relative_humidity', 'wet_bulb_temperature', 'mean_temperature']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      year  month  total_rainfall  no_of_rainy_days  mean_relative_humidity  \
# 342  2010      7           298.5                18                    84.8
#
#      wet_bulb_temperature  mean_temperature
# 342                  25.6              27.7

# %%
# month has the lowest total rainfall in 2010

rain_df.loc[rain_df['year']==2010][['year', 'month', 'total_rainfall', 'no_of_rainy_days','mean_relative_humidity', 'wet_bulb_temperature', 'mean_temperature']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#      year  month  total_rainfall  no_of_rainy_days  mean_relative_humidity  \
# 337  2010      2             6.3                 4                    77.3
#
#      wet_bulb_temperature  mean_temperature
# 337                  25.6              28.9

# %%
# month has the highest total rainfall in 2020

rain_df.loc[rain_df['year']==2020][['year', 'month', 'total_rainfall', 'no_of_rainy_days', 'mean_relative_humidity', 'wet_bulb_temperature', 'mean_temperature']].sort_values(by = 'total_rainfall', ascending=False).head(1)
# Out:
#      year  month  total_rainfall  no_of_rainy_days  mean_relative_humidity  \
# 460  2020      5           255.6                16                    79.1
#
#      wet_bulb_temperature  mean_temperature
# 460                  26.0              28.9

# %%
# month has the lowest total rainfall in 2020

rain_df.loc[rain_df['year']==2020][['year', 'month', 'total_rainfall', 'no_of_rainy_days', 'mean_relative_humidity', 'wet_bulb_temperature', 'mean_temperature']].sort_values(by = 'total_rainfall', ascending=True).head(1)
# Out:
#      year  month  total_rainfall  no_of_rainy_days  mean_relative_humidity  \
# 457  2020      2            65.0                 8                    76.0
#
#      wet_bulb_temperature  mean_temperature
# 457                  24.5              27.9

# %% [markdown]
# ** From the above analyses, we can determine that
#
# The highest rainfall months:
# - 1990: 9
# - 2000:11
# - 2010: 7
# - 2020: 5
#
# The lowest rain fall months:
# - 1990: 2
# - 2000: 9
# - 2010: 2
# - 2020: 2
#
# ** As a result, we can speculate that the higher rain falls are in the months in the second half of the year. The lower rain falls are in the months in the first half of the year.

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %%
# correlation of rain_df
rain_df.corr()
# Out:
#                                           date  no_of_rainy_days  \
# date                                  1.000000          0.102512
# no_of_rainy_days                      0.102512          1.000000
# total_rainfall                       -0.016002          0.684252
# year                                  0.999701          0.092628
# month                                 0.008113          0.403960
# mean_relative_humidity               -0.396904          0.582346
# mean_sunshine_hrs                     0.110229         -0.679018
# wet_bulb_temperature                  0.098005          0.010883
# mean_temperature                      0.326184         -0.362360
# total_international_visitor_arrivals  0.930037          0.099200
#
#                                       total_rainfall      year     month  \
# date                                       -0.016002  0.999701  0.008113
# no_of_rainy_days                            0.684252  0.092628  0.403960
# ...

# %%
# seaborn heatmap visualization of pearson correlation coefficients between numeric variables in our dataframe
plt.figure(figsize=(40,40))
ax = sns.heatmap(rain_df.corr(numeric_only=True), annot=True, annot_kws={'size': 30}, vmin=-1, vmax=1, cmap='coolwarm', cbar=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_yticklabels(ax.get_yticklabels(), rotation=40, ha="right")
plt.title('Correlation Map', fontsize=50)
plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
plt.tight_layout()
plt.savefig('corrmap.png');

# %% [markdown]
# **Correlation analysis:**
#
#  1. total_rainfall and no_of_rainy_days are moderately correlated at 0.68
#
#  2. total_rainfall and mean_rh are moderately correlated at 0.59
#
#  3. total_rainfall and mean_sunshine_hrs are negatively moderately correlated at -0.58, meaning that the higher the sunshine hours, the lower the total rainfall
#
#  4. total_rainfall and mean_temp are negatively moderately correlated at 0.51
#
#  5. total_rainfall and wet_bulb_temperature have no correlation

# %%
# Histogram of rain_df
plt.figure(figsize=(30,30))
plt.subplot(3, 3, 1)
plt.hist(rain_df['no_of_rainy_days'], range=[0, 30], bins=15)
plt.title('Histogram of no_of_rainy_days', fontsize=30) 
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('number of rainy days in days')
plt.subplot(3, 3, 2)
plt.hist(rain_df['total_rainfall'])
plt.title('Histogram of total rainfall', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('total rainfall in mm')
plt.subplot(3, 3, 3)
plt.hist(rain_df['mean_relative_humidity'])
plt.title('Histogram of mean_relative_humidity', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('mean_relative_humidity in %')
plt.subplot(3, 3, 4)
plt.hist(rain_df['mean_sunshine_hrs'])
plt.title('Histogram of mean sunshine hours', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('mean_sunshine_hours in hours')
plt.subplot(3, 3, 5)
plt.hist(rain_df['mean_temperature'])
plt.title('Histogram of mean temperature', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('mean temperature in celsius')
plt.subplot(3, 3, 6)
plt.hist(rain_df['wet_bulb_temperature'])
plt.title('Histogram of wet bulb temperature', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('wet bulb temperature in celsius')
plt.subplot(3, 3, 7)
plt.hist(rain_df['total_international_visitor_arrivals'])
plt.title('Histogram of total international visitor arrivals', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('total international visitors in ')
plt.savefig('hist.png')
;
# Out:
# ''

# %% [markdown]
# **Histogram Analysis**
#
# - Number of rainy days: normally distributed
# - Total rainfall: right skewed, majority is around 100-200 mm
# - Mean rh: left skewes, majority is around 82-85
# - Mean sunshine hours: normally distributed
# - Mean temperature: normally distributed
# - Wet bulb temperature: normally distributed

# %%
# Bar plot of total rainfall by month
mean_rainfall = rain_df.groupby("month")["total_rainfall"].mean().round(1)

plt.figure(figsize=(10, 10))
ax = sns.barplot(x=mean_rainfall.index, y=mean_rainfall, errorbar=None, color="steelblue")
ax.bar_label(ax.containers[0])
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.title('Total Rainfall')
plt.ylabel('total_rainfall (in mm)')
plt.savefig('rainfall.png');

# %% [markdown]
# **Analysis of the total rainfall by month**
#
# - December, November, and January are the top three months with highest rainfalls
# - February, June and September are the three months with lowest rainfalls

# %%
# Bar plot of number of rainy days by month
mean_rainday = rain_df.groupby("month")["no_of_rainy_days"].mean().round(1)

plt.figure(figsize=(10, 10))
ax = sns.barplot(x=mean_rainday.index, y=mean_rainday, errorbar=None, color="steelblue")
ax.bar_label(ax.containers[0])
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.title('Number of Rainy Days by Month')
plt.ylabel('no_of_rainy_days (in days)')
plt.savefig('rainday.png');

# %% [markdown]
# **Analysis of number of rainy days by month**
#
# - November, December, and October are the top 3 months with highest number of rainy days
# - February, March, June, and  September are among the months with lowest number of rainy days compared to the rest of the year

# %%
# Bar plot of relative humidity days by month
mean_humid = rain_df.groupby("month")["mean_relative_humidity"].mean().round(1)

plt.figure(figsize=(10, 5))
ax = sns.barplot(x=mean_humid.index, y=mean_humid, errorbar=None, color="steelblue")
ax.bar_label(ax.containers[0])
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.title('Mean Relative Humidity by month')
plt.ylabel('mean_rh (in %)')
plt.savefig('humidity.png');

# %% [markdown]
# **Analysis of relative humidity by month**
#
# - Relative humidity is constant all year
# - Relative humidity is highest during December and November, and lowest during February, July, and August

# %%
# Bar plot of sunshine hours by month
mean_sunshine = rain_df.groupby("month")["mean_sunshine_hrs"].mean().round(1)

plt.figure(figsize=(10, 10))
ax = sns.barplot(x=mean_sunshine.index, y=mean_sunshine, errorbar=None, color="steelblue")
ax.bar_label(ax.containers[0])
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.title('Mean Sunshine Hours by month')
plt.ylabel('mean_sunshine_hrs (in hrs)')
plt.savefig('sunshine_hr.png');

# %% [markdown]
# **Analysis of mean sunshine hours by month**
#
# - Sunshine hours are highest during February and lowest during November and December

# %%
# Bar plot of temperature by month
mean_temp = rain_df.groupby("month")["mean_temperature"].mean().round(1)

plt.figure(figsize=(10, 5))
ax = sns.barplot(x=mean_temp.index, y=mean_temp, errorbar=None, color="steelblue")
ax.bar_label(ax.containers[0])
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.title('Mean Temperature by month')
plt.ylabel('mean_temperature (in celsius)')
plt.savefig('temp.png');

# %% [markdown]
# **Analysis of temperature by month**
#
# - Temperature is constant all year.
# - The highest temperature is at May and the lowest is uting December and January

# %%
# Bar plot of wet bulb temperature by month
mean_wtemp = rain_df.groupby("month")["wet_bulb_temperature"].mean().round(1)

plt.figure(figsize=(10, 5))
ax = sns.barplot(x=mean_wtemp.index, y=mean_wtemp, errorbar=None, color="steelblue")
ax.bar_label(ax.containers[0])
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.title('Wet Bulb Temperature by month')
plt.ylabel('wet bulb temperature (in celsius)')
plt.savefig('wetbulb.png');

# %% [markdown]
# **Analysis of wet bulb temperature by month**
#
# - Wet bulb temperature is constant all year round at approximately 26
# - Highest wet bulb temperature during May and lowest during January

# %%
# Bar plot of International Visitors by month
mean_visit = rain_df.groupby("month")["total_international_visitor_arrivals"].mean().round(1)

plt.figure(figsize=(10, 10))
ax = sns.barplot(x=mean_visit.index, y=mean_visit, errorbar=None, color="steelblue")
ax.bar_label(ax.containers[0])
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.title('International Visitors by month')
plt.ylabel('total_interational_visitor_arrivals (in thousands)')
plt.savefig('visitor.png');

# %% [markdown]
# **Analysis of total international visitors arrival by month**
#
# - Number of visitors are at the highest on July, followed by August.
# - February has the lowest number of visitors

# %%
# Box plot of rain_df
plt.figure(figsize=(60, 60))
plt.subplot(3, 3, 1)
sns.boxplot(data=rain_df, y='total_rainfall', width=0.8)
plt.yticks(fontsize=50)
plt.ylabel('total_rainfall', fontsize=50)
plt.title('Total Rainfall Boxplot', fontsize=50)
plt.subplot(3, 3, 2)
sns.boxplot(data=rain_df, y='no_of_rainy_days', width=0.8)
plt.yticks(fontsize=50)
plt.ylabel('no_of_rainy_days', fontsize=50)
plt.title('Number of Rainy Days Boxplot', fontsize=50)
plt.subplot(3, 3, 3)
sns.boxplot(data=rain_df, y='mean_relative_humidity', width=0.8)
plt.yticks(fontsize=50)
plt.ylabel('mean_relative_humidity', fontsize=50)
plt.title('Relative Humidity Boxplot', fontsize=50)
plt.subplot(3, 3, 4)
sns.boxplot(data=rain_df, y='mean_sunshine_hrs', width=0.8)
plt.yticks(fontsize=50)
plt.ylabel('mean_sunshine_hrs', fontsize=50)
plt.title('Sunshine Hours Boxplot', fontsize=50)
plt.subplot(3, 3, 5)
sns.boxplot(data=rain_df, y='mean_temperature', width=0.8)
plt.yticks(fontsize=50)
plt.ylabel('mean_temp', fontsize=50)
plt.title('Temperature Boxplot', fontsize=50)
plt.subplot(3, 3, 6)
sns.boxplot(data=rain_df, y='wet_bulb_temperature', width=0.8)
plt.yticks(fontsize=50)
plt.ylabel('wet_bulb_temperature', fontsize=50)
plt.title('Wet Bulb Temperature Boxplot', fontsize=50)
plt.subplot(3, 3, 7)
sns.boxplot(data=rain_df, y='total_international_visitor_arrivals', width=0.8)
plt.yticks(fontsize=50)
plt.ylabel('total_international_visitor_arrivals', fontsize=50)
plt.title('Total International Visitor Arrivals Boxplot', fontsize=50)
plt.savefig('boxplot.png');

# %% [markdown]
# **Box plot Analysis**
#
# - Outliers are presented significantly in Total rainfall and moderately presented in Total International Visitor Arrivals

# %%
# Scatter plot of number of rainy days and total rainfall
plt.figure(figsize=(10, 10))
sns.scatterplot(data=rain_df, 
                x='no_of_rainy_days', 
                y='total_rainfall',
               s=50)
plt.title('Relationship of Number of Rainy Days and Total Rainfall')
plt.ylabel('total_rainfall (in mm)')
plt.xlabel('no_of_rainy_days (in days)')
plt.savefig('corr_day_rain.png');

# %% [markdown]
# **Analysis of relationship between number of rainy days and total rainfall**
#
# - Higher number of rainy days mean higher rainfall

# %%
# Scatter plot of sunshine hours and total rainfall
plt.figure(figsize=(10, 10))
sns.scatterplot(data=rain_df, 
                x='mean_sunshine_hrs', 
                y='total_rainfall',
               s=50)
plt.title('Relationship of Sunshine Hours and Total Rainfall')
plt.ylabel('total_rainfall (in mm)')
plt.xlabel('mean_sunshine_hrs (in hrs)')
plt.savefig('corr_sun_rain.png');

# %% [markdown]
# **Analysis of relationship between sunshine hours and total rainfall**
#
# - Higher sunshine hours mean lesser rainfall

# %%
# Scatter plot of relative humidity and total rain fall
plt.figure(figsize=(10, 10))
sns.scatterplot(data=rain_df, x='mean_relative_humidity', y='total_rainfall', s=60)
plt.title('Relationship of Relative Humidity and Total Rainfall')
plt.ylabel('total_rainfall (in mm)')
plt.xlabel('mean_rh (in %)')
plt.savefig('corr_rh_rain.png');

# %% [markdown]
# **Analysis of total rainfall and relative humidity**
#
# - The higher the relative humidity, the higher the rainfall

# %%
# Scatter plot of mean temperature and total rainfall
plt.figure(figsize=(10, 10))
sns.scatterplot(data=rain_df, x='mean_temperature', y='total_rainfall', s=60)
plt.title('Relationship of Mean Temperature and Total Rainfall')
plt.ylabel('total_rainfall (in mm)')
plt.xlabel('mean temperature (in celsius)')
plt.savefig('corr_temp_rain.png');

# %% [markdown]
# **Analysis of mean temperature and total rainfall**
#
# - Moderately negative relationship where total rainfall is higher when the temperature is lower, compare to when the temperature is high

# %%
# Scatter plot of wet bulb temperature and rainfall
plt.figure(figsize=(10, 10))
sns.scatterplot(data=rain_df, x='wet_bulb_temperature', y='total_rainfall', s=60)
plt.ylabel('total_rainfall (in mm)')
plt.xlabel('wet_bulb_temperature (in celsius)')
plt.title('Relationship of Wet Bulb Temperature and Total Rainfall')
plt.savefig('corr_wet_bulb.png');

# %% [markdown]
# **Analysis of wet bulb temperature and total rainfall**
#
# - There is no clear correlation between wetbulb and total rainfall

# %%
# Scatter plot of international visitors and total rainfall
plt.figure(figsize=(10, 10))
sns.scatterplot(data=rain_df, y='total_international_visitor_arrivals', x='total_rainfall', s=60)
plt.title('Relationship of International Visitors Arrival and Total Rainfall')
plt.ylabel('total_international_visitor_arrivals (in millions)')
plt.xlabel('total_rainfall (in mm)')
plt.savefig('corr_visit_rain.png');

# %% [markdown]
# **Analysis of number of visitors and total rainfall**
#
# - Number of visitors are aggregated within the range of 0-300 mm of rainfall
# - Data point is low and dispersed once the total rainfall increases from 300 mm

# %%
# Comparing rainfall and number of rainy days barplot and scatterplot
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
ax = sns.barplot(data=rain_df, y='total_rainfall', x='month', errorbar=None, color='steelblue')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('total_rainfall')
plt.title('Total Rainfall')
plt.subplot(2, 2, 3)
ax = sns.barplot(data=rain_df, y='no_of_rainy_days', x= 'month', errorbar=None, color='teal')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('no_of_rainy_days')
plt.title('Number of Rainy Days')
plt.subplot(2, 2, 2)
sns.scatterplot(data=rain_df, y='total_rainfall', x='no_of_rainy_days')
plt.yticks()
plt.ylabel('total rainfall')
plt.title('Total Rainfall vs. Number of Rainy Days')
plt.savefig('rainday_rainfall.png');

# %% [markdown]
# **Analysis of rainfall and number of rainy days comparison**
# - Positive relationship exists between total rainfall and number of rainy days
# - Bar charts of both features are moderately aligned, where high rainfall values correspond with rainy days values. However, January charts are not matched

# %%
# Comparing rainfall and number of rainy days barplot and scatterplot
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
ax = sns.barplot(data=rain_df, y='total_rainfall', x='month', errorbar=None, color='steelblue')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('total_rainfall')
plt.title('Total Rainfall')
plt.subplot(2, 2, 3)
sns.barplot(data=rain_df, y='mean_sunshine_hrs', x= 'month', errorbar=None, color='teal')
plt.yticks()
plt.ylabel('mean_sunshine_hours')
plt.title('Mean Sunshine Hours')
plt.subplot(2, 2, 2)
ax = sns.scatterplot(data=rain_df, y='total_rainfall', x='mean_sunshine_hrs')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('total rainfall')
plt.title('Total Rainfall vs. Mean Sunshine Hours')
plt.savefig('sunshine_rainfall.png');
# Out:
# /var/folders/0n/kzwpck_52r3g7z87p_fp5jlw0000gn/T/ipykernel_56872/2594792401.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# %% [markdown]
# **Analysis of rainfall and mean sunshine hours comparison**
# - Scatterplot shows negative relationship, where less sunshine hours lead to higher rainfall
# - both bar charts correspond to the scatterplot where high rainfall values lead to less sunshine hours

# %%
# Comparing rainfall and relative humidity barplot and scatterplot
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
ax = sns.barplot(data=rain_df, y='total_rainfall', x='month', errorbar=None, color='steelblue')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('total_rainfall')
plt.title('Total Rainfall')
plt.subplot(2, 2, 3)
ax = sns.barplot(data=rain_df, y='mean_relative_humidity', x= 'month', errorbar=None, color='teal')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('mean_relative_humidity')
plt.title('Mean Relative Humidity')
plt.subplot(2, 2, 2)
sns.scatterplot(data=rain_df, y='total_rainfall', x='mean_relative_humidity')
plt.yticks()
plt.ylabel('total rainfall')
plt.title('Total Rainfall vs. Mean Relative Humidity')
plt.savefig('rh_rainfall.png');

# %% [markdown]
# **Analysis of rainfall and relative humidity comparison**
# - Scatterplot shows positive relationship where higher mean_rh leads to higher rainfall
# - Both bar charts correspond to the scatterplot of positive relationship

# %%
# Comparing rainfall and mean temperature barplot and scatterplot
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
ax = sns.barplot(data=rain_df, y='total_rainfall', x='month', errorbar=None, color='steelblue')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('total_rainfall')
plt.title('Total Rainfall')
plt.subplot(2, 2, 3)
sns.barplot(data=rain_df, y='mean_temperature', x= 'month', errorbar=None, color='teal')
plt.yticks()
plt.ylabel('mean_temperature')
plt.title('Mean Temperature')
plt.subplot(2, 2, 2)
ax = sns.scatterplot(data=rain_df, y='total_rainfall', x='mean_temperature')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('total rainfall')
plt.title('Total Rainfall vs. Mean Temperature')
plt.savefig('temp_rainfall.png');
# Out:
# /var/folders/0n/kzwpck_52r3g7z87p_fp5jlw0000gn/T/ipykernel_56872/2361425307.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# %% [markdown]
# **Analysis of rainfall and mean temperature comparison**
# - Scatterplot shows negative relationship where higher mean temperature leads to higher rainfall
# - Both bar charts correspond to the scatterplot of negative relationship

# %%
# Comparing rainfall and wet bulb temperature barplot and scatterplot
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
ax = sns.barplot(data=rain_df, y='total_rainfall', x='month', errorbar=None, color='steelblue')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('total_rainfall')
plt.title('Total Rainfall')
plt.subplot(2, 2, 3)
ax = sns.barplot(data=rain_df, y='wet_bulb_temperature', x= 'month', errorbar=None, color='teal')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('wet_bulb_temperature')
plt.title('Wet Bulb Temperature')
plt.subplot(2, 2, 2)
sns.scatterplot(data=rain_df, y='total_rainfall', x='wet_bulb_temperature')
plt.yticks()
plt.ylabel('total rainfall')
plt.title('Total Rainfall vs. Wet Bulb Temperature')
plt.savefig('wetbulb_rainfall.png');

# %% [markdown]
# **Analysis of rainfall and wet bulb temperature comparison**
# - Scatterplot shows no relationship
# - Both bar charts do not aligned

# %%
# Comparing rainfall and total international visitor arrivals barplot and scatterplot
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
ax = sns.barplot(data=rain_df, y='total_rainfall', x='month', errorbar=None, color='steelblue')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('total_rainfall')
plt.title('Total Rainfall')
plt.subplot(2, 2, 3)
ax = sns.barplot(data=rain_df, y='total_international_visitor_arrivals', x= 'month', errorbar=None, color='teal')
ax.set(xticklabels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.yticks()
plt.ylabel('total_international_visitor_arrivals')
plt.title('Total International Visitors')
plt.subplot(2, 2, 2)
sns.scatterplot(data=rain_df, x='total_rainfall', y='total_international_visitor_arrivals')
plt.yticks()
plt.ylabel('total_international_visitor_arrivals')
plt.title('Total Rainfall vs. Total International Visitors')
plt.savefig('visitor_rainfall.png');

# %% [markdown]
# **Analysis of rainfall and total international visitors comparison**
# - Scatterplot shows no relationship.
# - More visitors are aggregated within the lower rainfall than higher rainfall
# - Both bar charts do not aligned. However, it can be seen that more visitors visit Singapore during July and August

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Conclusion:
# - From the analysis of the data, rainfall amount in Singapore is at the lowest amount during February. June and September are also among the low rainfall months. December, November, and January are among the months with highest rainfall
# - Factors that contribute to rainfall are:
#     1) sunshine hours, where less duration of sunshine means more rain
#     2) relative humidity, where higher humidity means higher amount of rainfall
#     3) mean temperature, where lower temperature likely to cause more rainfall
#     4) number of rainy days, where more rainy days means higher amount of rainfall
#     (These factors come from the correlation marix, where the number equal or above 0.5 means some correlation exists)
#
# - Additionally, when analyzing the number of visitors per month and total rainfall per month, there is no correlation. However, the visual does show that more visitors visit Singapore when amount of rainfall is low (0-300). This is incongruent with the chart that shows that most visitors come to Singapore during July and August which is the summer break period and the rainfall is relatively low.
#
# Recommendation
# - The tourism industry should promote to international visitors to visit Singapore during February when the amount of rainfall is the lowest, it has the least number of rainy days, and the number of visitors is lower comparing to July and August where the number of visitors are the highest (peak season), although the amount of rainfall is also low. Other optimal months to visit are June and September because the rainfall amount and the number of rainy days are low, as well not many visitors.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
